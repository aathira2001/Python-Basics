# %%
a=int(input("length"))
b=int(input('breadth'))
print('length of the rectangle=',a)
print('breadth of the rectangle=',b)
# Out:
# length10
# breadth20
# length of the rectangle= 10
# breadth of the rectangle= 20

# %%
print('Area of the rectangle=',a*b)
# Out:
# Area of the rectangle= 200

# %%
if(a==b):
  print("It is a square")
else:
  print("it is a rectangle")
# Out:
# it is a rectangle
